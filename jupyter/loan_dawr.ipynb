# %%
# import package
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Datacleaning

# %% [markdown]
# ### Read the database

# %%
df= pd.read_csv('../data_raw/train_u6lujuX_CVtuZ9i.csv')
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %% [markdown]
# ### Check that variable types are correct

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    object
#  2   Married            611 non-null    object
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      582 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB

# %%
# View missing values
df.isnull().sum().sort_values(ascending=False)
# Out:
# Credit_History       50
# Self_Employed        32
# LoanAmount           22
# Dependents           15
# Loan_Amount_Term     14
# Gender               13
# Married               3
# Loan_ID               0
# Education             0
# ApplicantIncome       0
# CoapplicantIncome     0
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
df.describe(include = 'O')
# Out:
#          Loan_ID Gender Married Dependents Education Self_Employed  \
# count        614    601     611        599       614           582
# unique       614      2       2          4         2             2
# top     LP001002   Male     Yes          0  Graduate            No
# freq           1    489     398        345       480           500
#
#        Property_Area Loan_Status
# count            614         614
# unique             3           2
# top        Semiurban           Y
# freq             233         422

# %%
df.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  592.000000         600.00000
# mean       5403.459283        1621.245798  146.412162         342.00000
# std        6109.041673        2926.248369   85.587325          65.12041
# min         150.000000           0.000000    9.000000          12.00000
# 25%        2877.500000           0.000000  100.000000         360.00000
# 50%        3812.500000        1188.500000  128.000000         360.00000
# 75%        5795.000000        2297.250000  168.000000         360.00000
# max       81000.000000       41667.000000  700.000000         480.00000
#
#        Credit_History
# count      564.000000
# mean         0.842199
# std          0.364878
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
doppel = df[df.duplicated()]
doppel
# Out:
# Empty DataFrame
# Columns: [Loan_ID, Gender, Married, Dependents, Education, Self_Employed, ApplicantIncome, CoapplicantIncome, LoanAmount, Loan_Amount_Term, Credit_History, Property_Area, Loan_Status]
# Index: []

# %% [markdown]
# ### Managing incorrectly recorded values

# %%
# verify unique values
#df.Dependents.unique()
df['Dependents'].unique()
# Out:
# array(['0', '1', '2', '3+', nan], dtype=object)

# %%
# replace object '3+' values with int 3 values
df['Dependents'].replace('3+', 3, inplace=True)

# %%
# verify unique values
df['Dependents'].unique()
# Out:
# array(['0', '1', '2', 3, nan], dtype=object)

# %%
#Convert object values to float64
df['Dependents']= df['Dependents'].astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    object
#  2   Married            611 non-null    object
#  3   Dependents         599 non-null    float64
#  4   Education          614 non-null    object
#  5   Self_Employed      582 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(5), int64(1), object(7)
# memory usage: 62.5+ KB

# %%
# categorie & num
cat_data = df.select_dtypes(object)
num_data = df.select_dtypes(np.number)

# %%
cat_data.head()
# Out:
#     Loan_ID Gender Married     Education Self_Employed Property_Area  \
# 0  LP001002   Male      No      Graduate            No         Urban
# 1  LP001003   Male     Yes      Graduate            No         Rural
# 2  LP001005   Male     Yes      Graduate           Yes         Urban
# 3  LP001006   Male     Yes  Not Graduate            No         Urban
# 4  LP001008   Male      No      Graduate            No         Urban
#
#   Loan_Status
# 0           Y
# 1           N
# 2           Y
# 3           Y
# 4           Y

# %%
num_data.head()
# Out:
#    Dependents  ApplicantIncome  CoapplicantIncome  LoanAmount  \
# 0         0.0             5849                0.0         NaN
# 1         1.0             4583             1508.0       128.0
# 2         0.0             3000                0.0        66.0
# 3         0.0             2583             2358.0       120.0
# 4         0.0             6000                0.0       141.0
#
#    Loan_Amount_Term  Credit_History
# 0             360.0             1.0
# 1             360.0             1.0
# 2             360.0             1.0
# 3             360.0             1.0
# 4             360.0             1.0

# %% [markdown]
# ### Fill in missing categorical values with modus

# %%
#Check missing values
cat_data.isnull().sum().sort_values(ascending=False)
# Out:
# Self_Employed    32
# Gender           13
# Married           3
# Loan_ID           0
# Education         0
# Property_Area     0
# Loan_Status       0
# dtype: int64

# %%
cat_data.head()
# Out:
#     Loan_ID Gender Married     Education Self_Employed Property_Area  \
# 0  LP001002   Male      No      Graduate            No         Urban
# 1  LP001003   Male     Yes      Graduate            No         Rural
# 2  LP001005   Male     Yes      Graduate           Yes         Urban
# 3  LP001006   Male     Yes  Not Graduate            No         Urban
# 4  LP001008   Male      No      Graduate            No         Urban
#
#   Loan_Status
# 0           Y
# 1           N
# 2           Y
# 3           Y
# 4           Y

# %%
# Fill Gender's missing values with the modus

mode_gender = cat_data['Gender'].mode().values[0]
cat_data['Gender'] = cat_data['Gender'].fillna(mode_gender, inplace= False)
cat_data['Gender'].isnull().sum()
# Out:
# 0

# %%
# Fill missing Self_Employed values with modus

mode_self_employed = cat_data['Self_Employed'].mode().values[0]
cat_data['Self_Employed'] = cat_data['Self_Employed'].fillna(mode_self_employed, inplace = False)
cat_data['Self_Employed'].isnull().sum()
# Out:
# 0

# %%
# Fill in missing Married values with modus

mode_married = cat_data['Married'].mode().values[0]
cat_data['Married'] = cat_data['Married'].fillna(mode_married, inplace = False)
cat_data['Married'].isnull().sum()
# Out:
# 0

# %%
cat_data.isnull().sum().sort_values(ascending=False)
# Out:
# Loan_ID          0
# Gender           0
# Married          0
# Education        0
# Self_Employed    0
# Property_Area    0
# Loan_Status      0
# dtype: int64

# %% [markdown]
# ### Fill in missing numerical values with the median

# %%
num_data.isnull().sum().sort_values(ascending=False)
# Out:
# Credit_History       50
# LoanAmount           22
# Dependents           15
# Loan_Amount_Term     14
# ApplicantIncome       0
# CoapplicantIncome     0
# dtype: int64

# %%
num_data = df.select_dtypes(np.number)
num_data
# Out:
#      Dependents  ApplicantIncome  CoapplicantIncome  LoanAmount  \
# 0           0.0             5849                0.0         NaN
# 1           1.0             4583             1508.0       128.0
# 2           0.0             3000                0.0        66.0
# 3           0.0             2583             2358.0       120.0
# 4           0.0             6000                0.0       141.0
# ..          ...              ...                ...         ...
# 609         0.0             2900                0.0        71.0
# 610         3.0             4106                0.0        40.0
# 611         1.0             8072              240.0       253.0
# 612         2.0             7583                0.0       187.0
# 613         0.0             4583                0.0       133.0
#
#      Loan_Amount_Term  Credit_History
# 0               360.0             1.0
# 1               360.0             1.0
# 2               360.0             1.0
# 3               360.0             1.0
# ...

# %%
numerische_spalten = ['Credit_History', 'LoanAmount', 'Dependents', 'Loan_Amount_Term']

# Fill missing values in numerical columns with the median
for spalte in numerische_spalten:
    med= num_data[spalte].median()
    num_data[spalte] = num_data[spalte].fillna(med, inplace=False)

# %%
print(num_data)
# Out:
#      Dependents  ApplicantIncome  CoapplicantIncome  LoanAmount  \
# 0           0.0             5849                0.0       128.0
# 1           1.0             4583             1508.0       128.0
# 2           0.0             3000                0.0        66.0
# 3           0.0             2583             2358.0       120.0
# 4           0.0             6000                0.0       141.0
# ..          ...              ...                ...         ...
# 609         0.0             2900                0.0        71.0
# 610         3.0             4106                0.0        40.0
# 611         1.0             8072              240.0       253.0
# 612         2.0             7583                0.0       187.0
# 613         0.0             4583                0.0       133.0
#
#      Loan_Amount_Term  Credit_History
# 0               360.0             1.0
# 1               360.0             1.0
# 2               360.0             1.0
# 3               360.0             1.0
# ...

# %%
num_data['Dependents']= num_data['Dependents'].astype(int)

# %%
print(num_data)
# Out:
#      Dependents  ApplicantIncome  CoapplicantIncome  LoanAmount  \
# 0             0             5849                0.0       128.0
# 1             1             4583             1508.0       128.0
# 2             0             3000                0.0        66.0
# 3             0             2583             2358.0       120.0
# 4             0             6000                0.0       141.0
# ..          ...              ...                ...         ...
# 609           0             2900                0.0        71.0
# 610           3             4106                0.0        40.0
# 611           1             8072              240.0       253.0
# 612           2             7583                0.0       187.0
# 613           0             4583                0.0       133.0
#
#      Loan_Amount_Term  Credit_History
# 0               360.0             1.0
# 1               360.0             1.0
# 2               360.0             1.0
# 3               360.0             1.0
# ...

# %%
num_data['Credit_History']= num_data['Credit_History'].astype(int)

# %%
print(num_data)
# Out:
#      Dependents  ApplicantIncome  CoapplicantIncome  LoanAmount  \
# 0             0             5849                0.0       128.0
# 1             1             4583             1508.0       128.0
# 2             0             3000                0.0        66.0
# 3             0             2583             2358.0       120.0
# 4             0             6000                0.0       141.0
# ..          ...              ...                ...         ...
# 609           0             2900                0.0        71.0
# 610           3             4106                0.0        40.0
# 611           1             8072              240.0       253.0
# 612           2             7583                0.0       187.0
# 613           0             4583                0.0       133.0
#
#      Loan_Amount_Term  Credit_History
# 0               360.0               1
# 1               360.0               1
# 2               360.0               1
# 3               360.0               1
# ...

# %%
num_data.isnull().sum().sort_values(ascending=False)
# Out:
# Dependents           0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# dtype: int64

# %%
num_data
# Out:
#      Dependents  ApplicantIncome  CoapplicantIncome  LoanAmount  \
# 0             0             5849                0.0       128.0
# 1             1             4583             1508.0       128.0
# 2             0             3000                0.0        66.0
# 3             0             2583             2358.0       120.0
# 4             0             6000                0.0       141.0
# ..          ...              ...                ...         ...
# 609           0             2900                0.0        71.0
# 610           3             4106                0.0        40.0
# 611           1             8072              240.0       253.0
# 612           2             7583                0.0       187.0
# 613           0             4583                0.0       133.0
#
#      Loan_Amount_Term  Credit_History
# 0               360.0               1
# 1               360.0               1
# 2               360.0               1
# 3               360.0               1
# ...

# %%
cat_data
# Out:
#       Loan_ID  Gender Married     Education Self_Employed Property_Area  \
# 0    LP001002    Male      No      Graduate            No         Urban
# 1    LP001003    Male     Yes      Graduate            No         Rural
# 2    LP001005    Male     Yes      Graduate           Yes         Urban
# 3    LP001006    Male     Yes  Not Graduate            No         Urban
# 4    LP001008    Male      No      Graduate            No         Urban
# ..        ...     ...     ...           ...           ...           ...
# 609  LP002978  Female      No      Graduate            No         Rural
# 610  LP002979    Male     Yes      Graduate            No         Rural
# 611  LP002983    Male     Yes      Graduate            No         Urban
# 612  LP002984    Male     Yes      Graduate            No         Urban
# 613  LP002990  Female      No      Graduate           Yes     Semiurban
#
#     Loan_Status
# 0             Y
# 1             N
# 2             Y
# 3             Y
# ...

# %% [markdown]
# ### Encoding

# %%
cat_data_hot = pd.get_dummies(cat_data, columns = ['Gender', 'Married','Education', 'Self_Employed', 'Property_Area', 'Loan_Status'], dtype=int)
cat_data_hot
# Out:
#       Loan_ID  Gender_Female  Gender_Male  Married_No  Married_Yes  \
# 0    LP001002              0            1           1            0
# 1    LP001003              0            1           0            1
# 2    LP001005              0            1           0            1
# 3    LP001006              0            1           0            1
# 4    LP001008              0            1           1            0
# ..        ...            ...          ...         ...          ...
# 609  LP002978              1            0           1            0
# 610  LP002979              0            1           0            1
# 611  LP002983              0            1           0            1
# 612  LP002984              0            1           0            1
# 613  LP002990              1            0           1            0
#
#      Education_Graduate  Education_Not Graduate  Self_Employed_No  \
# 0                     1                       0                 1
# ...

# %%
df_clean= pd.concat([num_data, cat_data_hot], axis=1)

# %%
df_clean
# Out:
#      Dependents  ApplicantIncome  CoapplicantIncome  LoanAmount  \
# 0             0             5849                0.0       128.0
# 1             1             4583             1508.0       128.0
# 2             0             3000                0.0        66.0
# 3             0             2583             2358.0       120.0
# 4             0             6000                0.0       141.0
# ..          ...              ...                ...         ...
# 609           0             2900                0.0        71.0
# 610           3             4106                0.0        40.0
# 611           1             8072              240.0       253.0
# 612           2             7583                0.0       187.0
# 613           0             4583                0.0       133.0
#
#      Loan_Amount_Term  Credit_History   Loan_ID  Gender_Female  Gender_Male  \
# 0               360.0               1  LP001002              0            1
# ...

# %%
df_clean.to_csv('../data_clean/data_train_clean.csv', index=False)

# %% [markdown]
# # Datacleaning von test-Dataset

# %%
df_test = pd.read_csv('../data_raw/test_Y3wMUE5_7gLdaTN.csv')
df_test
# Out:
#       Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0    LP001015   Male     Yes          0      Graduate            No
# 1    LP001022   Male     Yes          1      Graduate            No
# 2    LP001031   Male     Yes          2      Graduate            No
# 3    LP001035   Male     Yes          2      Graduate            No
# 4    LP001051   Male      No          0  Not Graduate            No
# ..        ...    ...     ...        ...           ...           ...
# 362  LP002971   Male     Yes         3+  Not Graduate           Yes
# 363  LP002975   Male     Yes          0      Graduate            No
# 364  LP002980   Male      No          0      Graduate            No
# 365  LP002986   Male     Yes          0      Graduate            No
# 366  LP002989   Male      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5720                  0       110.0             360.0
# ...

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 367 entries, 0 to 366
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            367 non-null    object
#  1   Gender             356 non-null    object
#  2   Married            367 non-null    object
#  3   Dependents         357 non-null    object
#  4   Education          367 non-null    object
#  5   Self_Employed      344 non-null    object
#  6   ApplicantIncome    367 non-null    int64
#  7   CoapplicantIncome  367 non-null    int64
#  8   LoanAmount         362 non-null    float64
#  9   Loan_Amount_Term   361 non-null    float64
#  10  Credit_History     338 non-null    float64
#  11  Property_Area      367 non-null    object
# dtypes: float64(3), int64(2), object(7)
# memory usage: 34.5+ KB

# %%
# verify unique values
#df.Dependents.unique()
df_test.Dependents.unique()
# Out:
# array(['0', '1', '2', '3+', nan], dtype=object)

# %%
# replace object '3+' values with int 3 values
df_test['Dependents'].replace('3+', 3, inplace=True)
# verify unique values
df_test['Dependents'].unique()
# Out:
# array(['0', '1', '2', 3, nan], dtype=object)

# %%
#Convert object values to float64
df_test['Dependents']= df['Dependents'].astype(float)

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 367 entries, 0 to 366
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            367 non-null    object
#  1   Gender             356 non-null    object
#  2   Married            367 non-null    object
#  3   Dependents         356 non-null    float64
#  4   Education          367 non-null    object
#  5   Self_Employed      344 non-null    object
#  6   ApplicantIncome    367 non-null    int64
#  7   CoapplicantIncome  367 non-null    int64
#  8   LoanAmount         362 non-null    float64
#  9   Loan_Amount_Term   361 non-null    float64
#  10  Credit_History     338 non-null    float64
#  11  Property_Area      367 non-null    object
# dtypes: float64(4), int64(2), object(6)
# memory usage: 34.5+ KB

# %%
# categorie & num
cat_data_test = df_test.select_dtypes(object)
num_data_test = df_test.select_dtypes(np.number)

# %%
# print
print(cat_data_test)
print(num_data_test)
# Out:
#       Loan_ID Gender Married     Education Self_Employed Property_Area
# 0    LP001015   Male     Yes      Graduate            No         Urban
# 1    LP001022   Male     Yes      Graduate            No         Urban
# 2    LP001031   Male     Yes      Graduate            No         Urban
# 3    LP001035   Male     Yes      Graduate            No         Urban
# 4    LP001051   Male      No  Not Graduate            No         Urban
# ..        ...    ...     ...           ...           ...           ...
# 362  LP002971   Male     Yes  Not Graduate           Yes         Urban
# 363  LP002975   Male     Yes      Graduate            No         Urban
# 364  LP002980   Male      No      Graduate            No     Semiurban
# 365  LP002986   Male     Yes      Graduate            No         Rural
# 366  LP002989   Male      No      Graduate           Yes         Rural
#
# [367 rows x 6 columns]
#      Dependents  ApplicantIncome  CoapplicantIncome  LoanAmount  \
# ...

# %% [markdown]
# #### Fill missing values

# %%
#Check missing values
cat_data_test.isnull().sum().sort_values(ascending=False)
# Out:
# Self_Employed    23
# Gender           11
# Loan_ID           0
# Married           0
# Education         0
# Property_Area     0
# dtype: int64

# %%
# Fill missing Self_Employed values with modus
cat_data_test['Self_Employed'] = cat_data_test['Self_Employed'].fillna(cat_data_test['Self_Employed'].mode().values[0], inplace = False)

# Fill Gender's missing values with the modus
cat_data_test['Gender'] = cat_data_test['Gender'].fillna(cat_data_test['Gender'].mode().values[0], inplace= False)

# %%
#Check missing values again
cat_data_test.isnull().sum().sort_values(ascending=False)
# Out:
# Loan_ID          0
# Gender           0
# Married          0
# Education        0
# Self_Employed    0
# Property_Area    0
# dtype: int64

# %%
#Check missing values 
num_data_test.isnull().sum().sort_values(ascending=False)
# Out:
# Credit_History       29
# Dependents           11
# Loan_Amount_Term      6
# LoanAmount            5
# ApplicantIncome       0
# CoapplicantIncome     0
# dtype: int64

# %%
spalten = ['Credit_History', 'LoanAmount', 'Dependents', 'Loan_Amount_Term']

# Fill missing values in numerical columns with the median
for spalte in spalten:
    med= num_data_test[spalte].median()
    num_data_test[spalte] = num_data_test[spalte].fillna(med, inplace=False)

# %%
#Check missing values again
num_data_test.isnull().sum().sort_values(ascending=False)
# Out:
# Dependents           0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# dtype: int64

# %% [markdown]
# ### Encoding

# %%
cat_data_test_hot = pd.get_dummies(cat_data_test, columns = ['Gender', 'Married','Education', 'Self_Employed', 'Property_Area'], dtype=int)
cat_data_test_hot
# Out:
#       Loan_ID  Gender_Female  Gender_Male  Married_No  Married_Yes  \
# 0    LP001015              0            1           0            1
# 1    LP001022              0            1           0            1
# 2    LP001031              0            1           0            1
# 3    LP001035              0            1           0            1
# 4    LP001051              0            1           1            0
# ..        ...            ...          ...         ...          ...
# 362  LP002971              0            1           0            1
# 363  LP002975              0            1           0            1
# 364  LP002980              0            1           1            0
# 365  LP002986              0            1           0            1
# 366  LP002989              0            1           1            0
#
#      Education_Graduate  Education_Not Graduate  Self_Employed_No  \
# 0                     1                       0                 1
# ...

# %%
df_test_clean= pd.concat([num_data_test, cat_data_test_hot], axis=1)
df_test_clean
# Out:
#      Dependents  ApplicantIncome  CoapplicantIncome  LoanAmount  \
# 0           0.0             5720                  0       110.0
# 1           1.0             3076               1500       126.0
# 2           0.0             5000               1800       208.0
# 3           0.0             2340               2546       100.0
# 4           0.0             3276                  0        78.0
# ..          ...              ...                ...         ...
# 362         0.0             4009               1777       113.0
# 363         0.0             4158                709       115.0
# 364         0.0             3250               1993       126.0
# 365         0.0             5000               2393       158.0
# 366         0.0             9200                  0        98.0
#
#      Loan_Amount_Term  Credit_History   Loan_ID  Gender_Female  Gender_Male  \
# 0               360.0             1.0  LP001015              0            1
# ...

# %%
df_test_clean.to_csv('../data_clean/data_test_clean.csv', index=False)
